# %%
# 1

name = "emil"
age = 20
grade = 98.5
is_student = True
fav_color = "orange"

print(f"name ={name}, age ={age}, grade ={grade}, is_student ={is_student}, fav_color ={fav_color}")
# Out:
# name =emil, age =20, grade =98.5, is_student =True, fav_color =orange

# %%
# 2
name = str("emil")
age = int(20)
grade = float(98.5)
is_student = bool(True)
fav_color = str("orange")


# 3

name = name.upper()
print(name)
# Out:
# EMIL

# %%
# 4

print(type(age+grade))
# Out:
# <class 'float'>

# %%
# 5

person = {name:str("emil"),age:int(20),
grade:float(98.5),
is_student:bool(True),
fav_color:str("orange")}

print(person)
print(f"My name is {person[name]}. I am {person[age]} years old. My favorite color is {person[fav_color]}. I will get a {person[grade]} in this class.")
# Out:
# {'EMIL': 'emil', 20: 20, 98.5: 98.5, True: True, 'orange': 'orange'}
# My name is emil. I am 20 years old. My favorite color is orange. I will get a 98.5 in this class.
